# %% [markdown]
# ## PCA Algorithm
# Principle component analysis is a part of unsupervised machine learning technique

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.
