# %%
import sklearn as sk
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
# read the data set
df=pd.read_csv("https://raw.githubusercontent.com/ritulsriva/Simple-linear-regression-on-tvmarketing-data/refs/heads/master/tvmarketing.csv")
df.head()

# example data set


# Data load karo
# data = {
#     'TV': [230.1, 44.5, 17.2, 151.5, 180.8, 38.2, 94.2, 177.0, 283.6, 232.1],
#     'Sales': [22.1, 10.4, 9.3, 18.5, 12.9, 7.6, 9.7, 12.8, 25.5, 13.4]
# }
# df = pd.DataFrame(data)
# df.to_csv("tv_marketing.csv", index=False)  # index=False = no extra number column
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
# visulize the data on graph format
plt.scatter(df["TV"], df["Sales"], c=df["TV"])
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("TV vs Sales")
plt.colorbar(label="TV")
plt.show()

# %%
X=df[["TV"]]  # independent variable
Y=df["Sales"] # dependent variable

# %%
Xtrain, Xtest, Ytrain,Ytest=train_test_split(X,Y,test_size=0.10, random_state=42)

# %%
Xtest
# Out:
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4

# %%
df.head()
data={201}
da=pd.DataFrame(data)
da
# Out:
#      0
# 0  201

# %%
model=LinearRegression()
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
print(model.predict(da))
# Out:
# [16.56162121]
# e:\Anaconda_setup\envs\jarvis-venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Ytest
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# Name: Sales, dtype: float64
