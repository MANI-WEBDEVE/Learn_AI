# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - ------------------------------------- 0.5/11.9 MB 479.2 kB/s eta 0:00:24
#      - ------------------------------------- 0.5/11.9 MB 479.2 kB/s eta 0:00:24
#      - ------------------------------------- 0.5/11.9 MB 479.2 kB/s eta 0:00:24
#      -- ------------------------------------ 0.8/11.9 MB 500.8 kB/s eta 0:00:23
#      -- ------------------------------------ 0.8/11.9 MB 500.8 kB/s eta 0:00:23
#      --- ----------------------------------- 1.0/11.9 MB 524.3 kB/s eta 0:00:21
# ...

# %% [markdown]
# ## Working On JSON File

# %%
import pandas as pd

# %%
data=pd.read_json("hospital.json")

# %%
data
# Out:
#             el                                                 fr  \
# 0        21450  {'Admission Type': 'Elective', 'Age': 57, 'Bil...
# 1      1736426  {'Admission Type': 'Elective', 'Age': 65, 'Bil...
# 2        40490  {'Admission Type': 'Elective', 'Age': 26, 'Bil...
# 3       892490  {'Admission Type': 'Emergency', 'Age': 70, 'Bi...
# 4      1768938  {'Admission Type': 'Urgent', 'Age': 66, 'Billi...
# ...        ...                                                ...
# 55495  1302634  {'Admission Type': 'Emergency', 'Age': 60, 'Bi...
# 55496  1149930  {'Admission Type': 'Emergency', 'Age': 20, 'Bi...
# 55497  1227850  {'Admission Type': 'Urgent', 'Age': 71, 'Billi...
# 55498  1369674  {'Admission Type': 'Urgent', 'Age': 30, 'Billi...
# 55499  1526122  {'Admission Type': 'Urgent', 'Age': 68, 'Billi...
#
#                                                       to         w
# 0      [{'el': 1721290, 'to': {'Admission Type': 'Ele...  1.000000
# ...

# %% [markdown]
# ## Working On SQL

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host="localhost", password="", user="root",database="world")

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'UK'", conn)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9456\518496701.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'UK'", conn)
# Empty DataFrame
# Columns: [ID, Name, CountryCode, District, Population]
# Index: []
