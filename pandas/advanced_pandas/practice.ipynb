# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/roberthryniewicz/datasets/master/airline-dataset/flights/flights.csv")

# %%
df.head(2)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
#
# [2 rows x 29 columns]

# %%
df[df["DayofMonth"] > 10]
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 25588  2008      1          11          5   1911.0        1845   2102.0
# 25589  2008      1          11          5    900.0         905   1418.0
# 25590  2008      1          11          5   1435.0        1435   1703.0
# 25591  2008      1          11          5    655.0         655    920.0
# 25592  2008      1          11          5   2043.0        2015   2306.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 25588        2040            WN        746  ...    4.0      9.0          0
# 25589        1440            WN       2126  ...    3.0      7.0          0
# 25590        1710            WN         45  ...    4.0      6.0          0
# 25591         930            WN         87  ...    4.0      7.0          0
# 25592        2240            WN        230  ...    4.0      7.0          0
# ...           ...           ...        ...  ...    ...      ...        ...
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 25588               NaN         0          22.0          0.0      0.0
# 25589               NaN         0           NaN          NaN      NaN
# 25590               NaN         0           NaN          NaN      NaN
# 25591               NaN         0           NaN          NaN      NaN
# 25592               NaN         0           0.0          0.0      0.0
# ...                 ...       ...           ...          ...      ...
# 99995               NaN         0           0.0          0.0      0.0
# 99996               NaN         0           NaN          NaN      NaN
# 99997               NaN         0          23.0          0.0      0.0
# 99998               NaN         0           NaN          NaN      NaN
# 99999               NaN         0           NaN          NaN      NaN
#
#        SecurityDelay  LateAircraftDelay
# 25588            0.0                0.0
# 25589            NaN                NaN
# 25590            NaN                NaN
# 25591            NaN                NaN
# 25592            0.0               26.0
# ...              ...                ...
# 99995            0.0              129.0
# 99996            NaN                NaN
# 99997            0.0               40.0
# 99998            NaN                NaN
# 99999            NaN                NaN
#
# [72513 rows x 29 columns]
