# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv'
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
numerical_columns=['longitude', 'latitude', 'housing_median_age', 'total_rooms']
numerical_columns_2=['total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']

# %%
for col in numerical_columns:
  plt.figure(figsize=(5,3))
  sns.histplot(x=df[col], kde=True)
  plt.show()
  plt.tight_layout()

# %%
for col in numerical_columns_2:
  plt.figure(figsize=(5,3))
  sns.histplot(x=df[col], kde=True)
  plt.show()
  plt.tight_layout()

# %%
sns.countplot(x=df['households'])
# Out:
# <Axes: xlabel='households', ylabel='count'>

# %%
sns.histplot(x=df['households'])
# Out:
# <Axes: xlabel='households', ylabel='Count'>

# %%
sns.histplot(x=df['median_income'], y=df['median_income'])
# Out:
# <Axes: xlabel='median_income', ylabel='median_income'>

# %%
sns.countplot(x=df['median_income'])
# Out:
# <Axes: xlabel='median_income', ylabel='count'>

# %%
sns.countplot(x=df['ocean_proximity'])
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='count'>

# %% [markdown]
# # **Data Cleaning and Preprocessing**

# %%
df_cleaned=df.copy()

# %%
df_cleaned.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df_cleaned.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY

# %%
# Step 1: Ratio calculate karo (non-null df_cleaned me)
df_cleaned['bedrooms_per_household'] = df_cleaned['total_bedrooms'] / df_cleaned['households']

# Step 2: Median ratio nikalo
median_ratio = df_cleaned['bedrooms_per_household'].median()  # Usually ~1.0 to 1.2

# Step 3: Missing values fill karo
# Jahan total_bedrooms null hai, wahan: households × median_ratio
df_cleaned['total_bedrooms'].fillna(df_cleaned['households'] * median_ratio, inplace=True)

# %%
df_cleaned.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    bedrooms_per_household
# 0                1.023810
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# longitude                   0
# latitude                    0
# housing_median_age          0
# total_rooms                 0
# total_bedrooms              0
# population                  0
# households                  0
# median_income               0
# median_house_value          0
# ocean_proximity             0
# bedrooms_per_household    207
# dtype: int64

# %%
df_cleaned['households']  * median_ratio
# Out:
# 0         132.160000
# 1        1193.635556
# 2         185.653333
# 3         229.706667
# 4         271.662222
#             ...
# 20635     346.133333
# 20636     119.573333
# 20637     454.168889
# 20638     366.062222
# 20639     555.911111
# Name: households, Length: 20640, dtype: float64

# %%
# now change the ocean convert numeric form
df_cleaned['ocean_proximity'].value_counts()

df_cleaned=pd.get_dummies(df_cleaned, columns=['ocean_proximity'], drop_first=True)

# %%
df_cleaned
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_cleaned['bedrooms_per_household'].fillna(1, inplace=True)

# %%
df_cleaned=df_cleaned.astype(int)

# %%
df_cleaned.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635       -121        39                  25         1665             374
# 20636       -121        39                  18          697             150
# 20637       -121        39                  17         2254             485
# 20638       -121        39                  18         1860             409
# 20639       -121        39                  16         2785             616
#
#        population  households  median_income  median_house_value  \
# 20635         845         330              1               78100
# 20636         356         114              2               77100
# 20637        1007         433              1               92300
# 20638         741         349              1               84700
# 20639        1387         530              2               89400
#
#        bedrooms_per_household  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# ...
